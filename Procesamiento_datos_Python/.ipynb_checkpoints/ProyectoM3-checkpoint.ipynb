# %% [markdown]
# ### Instalación de pandas !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('../DS/productos-verano-calificación-rendimiento_2020-08.csv')
df
# Out:
#                                         titulo_original  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress
# 2     2020 New Arrival Women Spring and Summer Beach...
# 3     Hot Summer Cool T Shirt for Women Fashion Tops...
# 4     Women Summer Shorts Lace Up Elastic Waistband ...
# ...                                                 ...
# 1568  New Fashion Women Bohemia Dandelion Print Tee ...
# 1569  10 Color Women Summer Shorts Lace Up Elastic W...
# 1570  New Men Siwmwear Beach-Shorts Men Summer Quick...
# 1571  Fashion Women Summer Sleeveless Dresses V Neck...
# 1572  Fashion Women Yoga Pants Slim Fit Fitness Runn...
#
#                                   Titulo_corto  precio  precio_al_por_menor  \
# 0     2020 Summer Vintage Flamingo Print  Paja   16.00                   14
# 1     Women's Casual Summer Sleeveless Sexy Mi    8.00                   22
# ...

# %% [markdown]
# ### Instalación de !pip install requests

# %%
import requests

endpoint = 'https://pokeapi.co/api/v2/pokemon'
r = requests.get(endpoint)
# Out:
# {'count': 1154,
#  'next': 'https://pokeapi.co/api/v2/pokemon?offset=20&limit=20',
#  'previous': None,
#  'results': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#   {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#   {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#   {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#   {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#   {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#   {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#   {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
# ...

# %%
r.json().keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
json = r.json()
result = json['results']

# %%
normalized = pd.json_normalize(result)

df = pd.DataFrame.from_dict(normalized)

df.head()
# Out:
#           name                                    url
# 0    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/
# 1      ivysaur   https://pokeapi.co/api/v2/pokemon/2/
# 2     venusaur   https://pokeapi.co/api/v2/pokemon/3/
# 3   charmander   https://pokeapi.co/api/v2/pokemon/4/
# 4   charmeleon   https://pokeapi.co/api/v2/pokemon/5/
# 5    charizard   https://pokeapi.co/api/v2/pokemon/6/
# 6     squirtle   https://pokeapi.co/api/v2/pokemon/7/
# 7    wartortle   https://pokeapi.co/api/v2/pokemon/8/
# 8    blastoise   https://pokeapi.co/api/v2/pokemon/9/
# 9     caterpie  https://pokeapi.co/api/v2/pokemon/10/
# 10     metapod  https://pokeapi.co/api/v2/pokemon/11/
# 11  butterfree  https://pokeapi.co/api/v2/pokemon/12/
# 12      weedle  https://pokeapi.co/api/v2/pokemon/13/
# 13      kakuna  https://pokeapi.co/api/v2/pokemon/14/
# 14    beedrill  https://pokeapi.co/api/v2/pokemon/15/
# 15      pidgey  https://pokeapi.co/api/v2/pokemon/16/
# ...

# %% [markdown]
#  ### Instalación de !pip install pymongo

# %%
from pymongo import MongoClient
from bson.json_util import dumps, loads

client = pymongo.MongoClient('localhost',27017)

#db = client ['test']
#db
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'proyecto', 'proyecto2']

# %%
db = client['proyecto']
db.list_collection_names()
# Out:
# ['craigslist',
#  'system.views',
#  'regiones',
#  'total_costo_inventario',
#  'economicos_marca',
#  'costo_min_max_modelo',
#  'costosos_marca']

# %%
collection = db['costosos_marca']
collection.count_documents({})
# Out:
# 100

# %%
for cr in collection.find():
    print(cr)
# Out:
# {'_id': ObjectId('625f16c55e80e0def19a5ccf'), 'id': '7308056031', 'url': 'https://eugene.craigslist.org/cto/d/florence-2007-toyota-tundra-trd-sr5/7308056031.html', 'region': 'eugene', 'region_url': 'https://eugene.craigslist.org', 'precio': 3736928711.0, 'anio': 2007, 'fabricante': 'toyota', 'modelo': 'tundra', 'condicion': 'excellent', 'cilindros': '8 cylinders', 'combustible': 'gas', 'odometro': 164000, 'titulostatus': 'clean', 'transmision': 'automatic', 'manejo': '4wd', 'tamanio': 'full-size', 'tipo': 'pickup', 'color': 'silver', 'imagen_url': 'https://images.craigslist.org/00v0v_3K0RsmdR5cuz_0CI0t2_600x450.jpg', 'descripcion': 'Selling my 2007 Toyota Tundra SR5 four wheel drive Amazing condition everything works as it should newer wheels and tires about 60% no leaks what so ever runs and drives great killer trim package contact for any further information no scams or emails will be answered or ridiculous low ball offers  text or call please CASH ONLY  show contact info  thanks f
# ...

# %%
cursor = collection.find()
list_cur = list(cursor)
json_data = dumps(list_cur)

json_data
# Out:
# '[{"_id": {"$oid": "625f16c55e80e0def19a5ccf"}, "id": "7308056031", "url": "https://eugene.craigslist.org/cto/d/florence-2007-toyota-tundra-trd-sr5/7308056031.html", "region": "eugene", "region_url": "https://eugene.craigslist.org", "precio": 3736928711.0, "anio": 2007, "fabricante": "toyota", "modelo": "tundra", "condicion": "excellent", "cilindros": "8 cylinders", "combustible": "gas", "odometro": 164000, "titulostatus": "clean", "transmision": "automatic", "manejo": "4wd", "tamanio": "full-size", "tipo": "pickup", "color": "silver", "imagen_url": "https://images.craigslist.org/00v0v_3K0RsmdR5cuz_0CI0t2_600x450.jpg", "descripcion": "Selling my 2007 Toyota Tundra SR5 four wheel drive Amazing condition everything works as it should newer wheels and tires about 60% no leaks what so ever runs and drives great killer trim package contact for any further information no scams or emails will be answered or ridiculous low ball offers  text or call please CASH ONLY  show contact info  thanks
# ...
