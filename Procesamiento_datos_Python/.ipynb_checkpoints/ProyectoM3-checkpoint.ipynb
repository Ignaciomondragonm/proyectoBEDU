# %% [markdown]
# # Módulo 3: Procesamiento de datos con Python
#
# ## Abrir achivo csv
#
# Archivos a utilizar:
# - [productos-verano-calificación-rendimiento_2020-08](../DS/productos-verano-calificación-rendimiento_2020-08.csv)
# - [categorias-unicas](../DS/categorias-unicas.csv)
# - [categorias-unicas-ordenadas-recuento](../DS/categorias-unicas-ordenadas-recuento.csv)
#
# Se requiere la instalación de pandas `!pip install pandas`

# %%
import pandas as pd
df = pd.read_csv('../DS/productos-verano-calificación-rendimiento_2020-08.csv')
df
# Out:
#                                         titulo_original  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress
# 2     2020 New Arrival Women Spring and Summer Beach...
# 3     Hot Summer Cool T Shirt for Women Fashion Tops...
# 4     Women Summer Shorts Lace Up Elastic Waistband ...
# ...                                                 ...
# 1568  New Fashion Women Bohemia Dandelion Print Tee ...
# 1569  10 Color Women Summer Shorts Lace Up Elastic W...
# 1570  New Men Siwmwear Beach-Shorts Men Summer Quick...
# 1571  Fashion Women Summer Sleeveless Dresses V Neck...
# 1572  Fashion Women Yoga Pants Slim Fit Fitness Runn...
#
#                                   Titulo_corto  precio  precio_al_por_menor  \
# 0     2020 Summer Vintage Flamingo Print  Paja   16.00                   14
# 1     Women's Casual Summer Sleeveless Sexy Mi    8.00                   22
# 2     2020 New Arrival Women Spring and Summer    8.00                   43
# 3     Hot Summer Cool T Shirt for Women Fashio    8.00                    8
# 4     Women Summer Shorts Lace Up Elastic Wais    2.72                    3
# ...                                        ...     ...                  ...
# 1568  New Fashion Women Bohemia Dandelion Prin    6.00                    9
# 1569  10 Color Women Summer Shorts Lace Up Ela    2.00                   56
# 1570  New Men Siwmwear Beach-Shorts Men Summer    5.00                   19
# 1571  Fashion Women Summer Sleeveless Dresses    13.00                   11
# 1572  Fashion Women Yoga Pants Slim Fit Fitnes    7.00                    6
#
#      comprador_de_divisas  unidades_vendidas  utiliza_refuerzos_publicitarios  \
# 0                     EUR                100                                0
# 1                     EUR              20000                                1
# 2                     EUR                100                                0
# 3                     EUR               5000                                1
# 4                     EUR                100                                1
# ...                   ...                ...                              ...
# 1568                  EUR              10000                                1
# 1569                  EUR                100                                1
# 1570                  EUR                100                                0
# 1571                  EUR                100                                0
# 1572                  EUR                100                                1
#
#       clasificacion  conteo_de_calificacion  calificacion_cinco_cuenta  ...  \
# 0              3.76                      54                       26.0  ...
# 1              3.45                    6135                     2269.0  ...
# 2              3.57                      14                        5.0  ...
# 3              4.03                     579                      295.0  ...
# 4              3.10                      20                        6.0  ...
# ...             ...                     ...                        ...  ...
# 1568           4.08                    1367                      722.0  ...
# 1569           3.07                      28                       11.0  ...
# 1570           3.71                      59                       24.0  ...
# 1571           2.50                       2                        0.0  ...
# 1572           4.07                      14                        8.0  ...
#
#       conteo_de_calificaciones_del_comerciante  calificacion_del_comerciante  \
# 0                                          568                      4.128521
# 1                                        17752                      3.899673
# 2                                          295                      3.989831
# 3                                        23832                      4.020435
# 4                                        14482                      4.001588
# ...                                        ...                           ...
# 1568                                      5316                      4.224605
# 1569                                      4435                      3.696054
# 1570                                       210                      3.961905
# 1571                                        31                      3.774194
# 1572                                      7023                      4.235939
#
#                 comerciante_id  el_comerciante_tiene_una_foto_de_perfil  \
# 0     595097d6a26f6e070cb878d1                                        0
# 1     56458aa03a698c35c9050988                                        0
# 2     5d464a1ffdf7bc44ee933c65                                        0
# 3     58cfdefdacb37b556efdff7c                                        0
# 4     5ab3b592c3911a095ad5dadb                                        0
# ...                        ...                                      ...
# 1568  5b507899ab577736508a0782                                        0
# 1569  54d83b6b6b8a771e478558de                                        0
# 1570  5b42da1bf64320209fc8da69                                        0
# 1571  5d56b32c40defd78043d5af9                                        0
# 1572  5a409cf87b584e7951b2e25f                                        0
#
#       foto_de_perfil_del_comerciante  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1568                             NaN
# 1569                             NaN
# 1570                             NaN
# 1571                             NaN
# 1572                             NaN
#
#                                      URL_del_producto  \
# 0     https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
# 1     https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2     https://www.wish.com/c/5ea10e2c617580260d55310a
# 3     https://www.wish.com/c/5cedf17ad1d44c52c59e4aca
# 4     https://www.wish.com/c/5ebf5819ebac372b070b0e70
# ...                                               ...
# 1568  https://www.wish.com/c/5d5fadc99febd9356cbc52ee
# 1569  https://www.wish.com/c/5eccd22b4497b86fd48f16b4
# 1570  https://www.wish.com/c/5e74be96034d613d42b52dfe
# 1571  https://www.wish.com/c/5eda07ab0e295c2097c36590
# 1572  https://www.wish.com/c/5e857321f53c3d2d8f25e7ed
#
#                                     imagen_del_producto  \
# 0     https://contestimg.wish.com/api/webimage/5e9ae...
# 1     https://contestimg.wish.com/api/webimage/58940...
# 2     https://contestimg.wish.com/api/webimage/5ea10...
# 3     https://contestimg.wish.com/api/webimage/5cedf...
# 4     https://contestimg.wish.com/api/webimage/5ebf5...
# ...                                                 ...
# 1568  https://contestimg.wish.com/api/webimage/5d5fa...
# 1569  https://contestimg.wish.com/api/webimage/5eccd...
# 1570  https://contestimg.wish.com/api/webimage/5e74b...
# 1571  https://contestimg.wish.com/api/webimage/5eda0...
# 1572  https://contestimg.wish.com/api/webimage/5e857...
#
#                ID_del_producto    tema mes_de_rastreo
# 0     5e9ae51d43d6a96e303acdb0  summer        2020-08
# 1     58940d436a0d3d5da4e95a38  summer        2020-08
# 2     5ea10e2c617580260d55310a  summer        2020-08
# 3     5cedf17ad1d44c52c59e4aca  summer        2020-08
# 4     5ebf5819ebac372b070b0e70  summer        2020-08
# ...                        ...     ...            ...
# 1568  5d5fadc99febd9356cbc52ee  summer        2020-08
# 1569  5eccd22b4497b86fd48f16b4  summer        2020-08
# 1570  5e74be96034d613d42b52dfe  summer        2020-08
# 1571  5eda07ab0e295c2097c36590  summer        2020-08
# 1572  5e857321f53c3d2d8f25e7ed  summer        2020-08
#
# [1573 rows x 43 columns]

# %% [markdown]
#  ## Conexión directa con Mongo DB
#
# Se requiere la instalación de pandas `!pip install pymongo`
#
# Para este ejemplo se conectara a servidor local, base de datos **Proyecto2**

# %%
from pymongo import MongoClient
from bson.json_util import dumps, loads

client = pymongo.MongoClient('localhost',27017)
#Lista bases de datos de servidor
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'proyecto', 'proyecto2']

# %%
#Utilizar base de datos proyecto2
db = client['proyecto2']
#Coleciones
db.list_collection_names()
# Out:
# ['categorias', 'ventas']

# %%
collection = db['ventas']
#Numero de documentos
collection.count_documents({})
# Out:
# 4704

# %%
#Ver informacion de cursor 
info = collection.find()
for cr in info:
    print(cr)
# Out:
# {'_id': ObjectId('625f328e5e80e0def19c042e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'AGO - Africa/Angola', ' Ingresos ': 66319.70378, ' Gastos ': 56708.15251}
# {'_id': ObjectId('625f328e5e80e0def19c042f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'AGO - Africa/Angola', ' Ingresos ': 122357.2829, ' Gastos ': 77039.77074}
# {'_id': ObjectId('625f328e5e80e0def19c0430'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'AGO - Africa/Angola', ' Ingresos ': 265278.8151, ' Gastos ': 215226.2085}
# {'_id': ObjectId('625f328e5e80e0def19c0431'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'AGO - Africa/Angola', ' Ingresos ': 130447.0207, ' Gastos ': 86964.68044}
# {'_id': ObjectId('625f328e5e80e0def19c0432'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'AGO - Africa/Angola', ' Ingresos ': 394602.2375, ' Gastos ': 326567.369}
# {'_id': ObjectId('625f328e5e80e0def19c0433'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'AGO - Africa/Angola', ' Ingresos ': 81152.13111, ' Gastos ': 69217.99418}
# {'_id': ObjectId('625f328e5e80e0def19c0434'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'AGO - Africa/Angola', ' Ingresos ': 44777.55887, ' Gastos ': 28193.2778}
# {'_id': ObjectId('625f328e5e80e0def19c0435'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'ARG - America/Argentina', ' Ingresos ': 88128.95446, ' Gastos ': 73914.60697}
# {'_id': ObjectId('625f328e5e80e0def19c0436'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'ARG - America/Argentina', ' Ingresos ': 135405.1283, ' Gastos ': 73857.3427}
# {'_id': ObjectId('625f328e5e80e0def19c0437'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'ARG - America/Argentina', ' Ingresos ': 464439.59, ' Gastos ': 417526.5001}
# {'_id': ObjectId('625f328e5e80e0def19c0438'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'ARG - America/Argentina', ' Ingresos ': 232219.795, ' Gastos ': 146212.4635}
# {'_id': ObjectId('625f328e5e80e0def19c0439'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'ARG - America/Argentina', ' Ingresos ': 566389.7439, ' Gastos ': 493775.6742}
# {'_id': ObjectId('625f328e5e80e0def19c043a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'ARG - America/Argentina', ' Ingresos ': 152275.2754, ' Gastos ': 131971.9054}
# {'_id': ObjectId('625f328e5e80e0def19c043b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'ARG - America/Argentina', ' Ingresos ': 62932.19377, ' Gastos ': 35570.37039}
# {'_id': ObjectId('625f328e5e80e0def19c043c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'AUS - Oceania/Australia', ' Ingresos ': 54365.02453, ' Gastos ': 39867.68465}
# {'_id': ObjectId('625f328e5e80e0def19c043d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'AUS - Oceania/Australia', ' Ingresos ': 87845.92378, ' Gastos ': 43124.36258}
# {'_id': ObjectId('625f328e5e80e0def19c043e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'AUS - Oceania/Australia', ' Ingresos ': 246268.9145, ' Gastos ': 197809.5475}
# {'_id': ObjectId('625f328e5e80e0def19c043f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'AUS - Oceania/Australia', ' Ingresos ': 114794.6733, ' Gastos ': 65050.31487}
# {'_id': ObjectId('625f328e5e80e0def19c0440'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'AUS - Oceania/Australia', ' Ingresos ': 313189.8152, ' Gastos ': 252509.2885}
# {'_id': ObjectId('625f328e5e80e0def19c0441'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'AUS - Oceania/Australia', ' Ingresos ': 92647.791, ' Gastos ': 70749.22222}
# {'_id': ObjectId('625f328e5e80e0def19c0442'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'AUS - Oceania/Australia', ' Ingresos ': 36987.75738, ' Gastos ': 19973.38899}
# {'_id': ObjectId('625f328e5e80e0def19c0443'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'AUT - Europa/Austria', ' Ingresos ': 21115.39872, ' Gastos ': 18300.01222}
# {'_id': ObjectId('625f328e5e80e0def19c0444'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'AUT - Europa/Austria', ' Ingresos ': 31740.77564, ' Gastos ': 17940.43841}
# {'_id': ObjectId('625f328e5e80e0def19c0445'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'AUT - Europa/Austria', ' Ingresos ': 71761.75362, ' Gastos ': 61510.07453}
# {'_id': ObjectId('625f328e5e80e0def19c0446'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'AUT - Europa/Austria', ' Ingresos ': 47157.72381, ' Gastos ': 27508.67222}
# {'_id': ObjectId('625f328e5e80e0def19c0447'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'AUT - Europa/Austria', ' Ingresos ': 125355.9747, ' Gastos ': 108183.9234}
# {'_id': ObjectId('625f328e5e80e0def19c0448'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'AUT - Europa/Austria', ' Ingresos ': 25327.67775, ' Gastos ': 21905.01859}
# {'_id': ObjectId('625f328e5e80e0def19c0449'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'AUT - Europa/Austria', ' Ingresos ': 15744.23211, ' Gastos ': 9913.035035}
# {'_id': ObjectId('625f328e5e80e0def19c044a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'BEL - Europa/Belgica', ' Ingresos ': 33098.74052, ' Gastos ': 29501.05133}
# {'_id': ObjectId('625f328e5e80e0def19c044b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'BEL - Europa/Belgica', ' Ingresos ': 60964.95956, ' Gastos ': 35562.89308}
# {'_id': ObjectId('625f328e5e80e0def19c044c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'BEL - Europa/Belgica', ' Ingresos ': 165824.69, ' Gastos ': 142135.4486}
# {'_id': ObjectId('625f328e5e80e0def19c044d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'BEL - Europa/Belgica', ' Ingresos ': 60519.95985, ' Gastos ': 38905.68848}
# {'_id': ObjectId('625f328e5e80e0def19c044e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'BEL - Europa/Belgica', ' Ingresos ': 301499.4364, ' Gastos ': 267238.1368}
# {'_id': ObjectId('625f328e5e80e0def19c044f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'BEL - Europa/Belgica', ' Ingresos ': 45934.81717, ' Gastos ': 38643.57635}
# {'_id': ObjectId('625f328e5e80e0def19c0450'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'BEL - Europa/Belgica', ' Ingresos ': 21563.6788, ' Gastos ': 12938.20728}
# {'_id': ObjectId('625f328e5e80e0def19c0451'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'BRA - America/Brasil', ' Ingresos ': 419500.7374, ' Gastos ': 343227.876}
# {'_id': ObjectId('625f328e5e80e0def19c0452'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'BRA - America/Brasil', ' Ingresos ': 746952.7518, ' Gastos ': 459663.2319}
# {'_id': ObjectId('625f328e5e80e0def19c0453'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'BRA - America/Brasil', ' Ingresos ': 1648038.611, ' Gastos ': 1478137.723}
# {'_id': ObjectId('625f328e5e80e0def19c0454'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'BRA - America/Brasil', ' Ingresos ': 771943.7361, ' Gastos ': 496249.5446}
# {'_id': ObjectId('625f328e5e80e0def19c0455'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'BRA - America/Brasil', ' Ingresos ': 3146255.53, ' Gastos ': 2784616.964}
# {'_id': ObjectId('625f328e5e80e0def19c0456'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'BRA - America/Brasil', ' Ingresos ': 521740.8668, ' Gastos ': 443869.0957}
# {'_id': ObjectId('625f328e5e80e0def19c0457'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'BRA - America/Brasil', ' Ingresos ': 290423.5874, ' Gastos ': 178722.2076}
# {'_id': ObjectId('625f328e5e80e0def19c0458'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'CAN - America/CanadA', ' Ingresos ': 986432.958, ' Gastos ': 878033.7318}
# {'_id': ObjectId('625f328e5e80e0def19c0459'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'CAN - America/CanadA', ' Ingresos ': 1559476.382, ' Gastos ': 1021725.905}
# {'_id': ObjectId('625f328e5e80e0def19c045a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'CAN - America/CanadA', ' Ingresos ': 4496490.233, ' Gastos ': 3771249.873}
# {'_id': ObjectId('625f328e5e80e0def19c045b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'CAN - America/CanadA', ' Ingresos ': 2043859.197, ' Gastos ': 1286874.309}
# {'_id': ObjectId('625f328e5e80e0def19c045c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'CAN - America/CanadA', ' Ingresos ': 6131577.591, ' Gastos ': 5499456.19}
# {'_id': ObjectId('625f328e5e80e0def19c045d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'CAN - America/CanadA', ' Ingresos ': 1419944.284, ' Gastos ': 1198077.99}
# {'_id': ObjectId('625f328e5e80e0def19c045e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'CAN - America/CanadA', ' Ingresos ': 840465.4642, ' Gastos ': 458435.7077}
# {'_id': ObjectId('625f328e5e80e0def19c045f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'CHE - Europa/Suiza', ' Ingresos ': 16629.95817, ' Gastos ': 13712.42165}
# {'_id': ObjectId('625f328e5e80e0def19c0460'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'CHE - Europa/Suiza', ' Ingresos ': 28586.13725, ' Gastos ': 17591.46908}
# {'_id': ObjectId('625f328e5e80e0def19c0461'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'CHE - Europa/Suiza', ' Ingresos ': 93057, ' Gastos ': 82601.1573}
# {'_id': ObjectId('625f328e5e80e0def19c0462'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'CHE - Europa/Suiza', ' Ingresos ': 30800.55634, ' Gastos ': 17966.9912}
# {'_id': ObjectId('625f328e5e80e0def19c0463'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'CHE - Europa/Suiza', ' Ingresos ': 98284.92135, ' Gastos ': 88046.90871}
# {'_id': ObjectId('625f328e5e80e0def19c0464'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'CHE - Europa/Suiza', ' Ingresos ': 25879.7574, ' Gastos ': 21637.17422}
# {'_id': ObjectId('625f328e5e80e0def19c0465'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'CHE - Europa/Suiza', ' Ingresos ': 13689.13615, ' Gastos ': 8619.085724}
# {'_id': ObjectId('625f328e5e80e0def19c0466'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'CHL - America/Chile', ' Ingresos ': 42928.91758, ' Gastos ': 38548.41579}
# {'_id': ObjectId('625f328e5e80e0def19c0467'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'CHL - America/Chile', ' Ingresos ': 72120.58154, ' Gastos ': 47251.41549}
# {'_id': ObjectId('625f328e5e80e0def19c0468'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'CHL - America/Chile', ' Ingresos ': 187513.512, ' Gastos ': 164646.0105}
# {'_id': ObjectId('625f328e5e80e0def19c0469'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'CHL - America/Chile', ' Ingresos ': 93383.22311, ' Gastos ': 57466.59884}
# {'_id': ObjectId('625f328e5e80e0def19c046a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'CHL - America/Chile', ' Ingresos ': 404123.9483, ' Gastos ': 345555.2601}
# {'_id': ObjectId('625f328e5e80e0def19c046b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'CHL - America/Chile', ' Ingresos ': 75610.2871, ' Gastos ': 60488.22968}
# {'_id': ObjectId('625f328e5e80e0def19c046c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'CHL - America/Chile', ' Ingresos ': 33389.15812, ' Gastos ': 21464.45879}
# {'_id': ObjectId('625f328e5e80e0def19c046d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'CHN - Asia/China', ' Ingresos ': 3076128.817, ' Gastos ': 2906941.732}
# {'_id': ObjectId('625f328e5e80e0def19c046e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'CHN - Asia/China', ' Ingresos ': 4370407.787, ' Gastos ': 2676874.77}
# {'_id': ObjectId('625f328e5e80e0def19c046f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'CHN - Asia/China', ' Ingresos ': 10605115.42, ' Gastos ': 9215479.602}
# {'_id': ObjectId('625f328e5e80e0def19c0470'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'CHN - Asia/China', ' Ingresos ': 5766279.468, ' Gastos ': 3422161.51}
# {'_id': ObjectId('625f328e5e80e0def19c0471'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'CHN - Asia/China', ' Ingresos ': 17039679.81, ' Gastos ': 14859178.41}
# {'_id': ObjectId('625f328e5e80e0def19c0472'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'CHN - Asia/China', ' Ingresos ': 4460386.781, ' Gastos ': 4119140.322}
# {'_id': ObjectId('625f328e5e80e0def19c0473'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'CHN - Asia/China', ' Ingresos ': 1951777.994, ' Gastos ': 1158337.809}
# {'_id': ObjectId('625f328e5e80e0def19c0474'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'CMR - Africa/Camerun', ' Ingresos ': 55838.48785, ' Gastos ': 50198.23656}
# {'_id': ObjectId('625f328e5e80e0def19c0475'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'CMR - Africa/Camerun', ' Ingresos ': 80186.6657, ' Gastos ': 53457.77713}
# {'_id': ObjectId('625f328e5e80e0def19c0476'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'CMR - Africa/Camerun', ' Ingresos ': 213831.1085, ' Gastos ': 176316.879}
# {'_id': ObjectId('625f328e5e80e0def19c0477'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'CMR - Africa/Camerun', ' Ingresos ': 119931.3609, ' Gastos ': 71958.81652}
# {'_id': ObjectId('625f328e5e80e0def19c0478'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'CMR - Africa/Camerun', ' Ingresos ': 540866.9216, ' Gastos ': 460140.5154}
# {'_id': ObjectId('625f328e5e80e0def19c0479'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'CMR - Africa/Camerun', ' Ingresos ': 87016.44479, ' Gastos ': 75715.60781}
# {'_id': ObjectId('625f328e5e80e0def19c047a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'CMR - Africa/Camerun', ' Ingresos ': 38851.00423, ' Gastos ': 21959.26326}
# {'_id': ObjectId('625f328e5e80e0def19c047b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'COL - America/Colombia', ' Ingresos ': 110701.5956, ' Gastos ': 86636.03135}
# {'_id': ObjectId('625f328e5e80e0def19c047c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'COL - America/Colombia', ' Ingresos ': 208135.5843, ' Gastos ': 113528.5005}
# {'_id': ObjectId('625f328e5e80e0def19c047d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'COL - America/Colombia', ' Ingresos ': 463101.675, ' Gastos ': 389593.4726}
# {'_id': ObjectId('625f328e5e80e0def19c047e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'COL - America/Colombia', ' Ingresos ': 237488.0385, ' Gastos ': 149529.5057}
# {'_id': ObjectId('625f328e5e80e0def19c047f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'COL - America/Colombia', ' Ingresos ': 992360.7321, ' Gastos ': 837304.3677}
# {'_id': ObjectId('625f328e5e80e0def19c0480'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'COL - America/Colombia', ' Ingresos ': 184625.2525, ' Gastos ': 154358.8177}
# {'_id': ObjectId('625f328e5e80e0def19c0481'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'COL - America/Colombia', ' Ingresos ': 84584.78082, ' Gastos ': 56389.85388}
# {'_id': ObjectId('625f328e5e80e0def19c0482'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'CRI - America/Costa Rica', ' Ingresos ': 10789.54433, ' Gastos ': 9577.235978}
# {'_id': ObjectId('625f328e5e80e0def19c0483'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'CRI - America/Costa Rica', ' Ingresos ': 16051.92945, ' Gastos ': 10701.2863}
# {'_id': ObjectId('625f328e5e80e0def19c0484'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'CRI - America/Costa Rica', ' Ingresos ': 35841.97945, ' Gastos ': 31814.79075}
# {'_id': ObjectId('625f328e5e80e0def19c0485'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'CRI - America/Costa Rica', ' Ingresos ': 17738.74237, ' Gastos ': 10643.24542}
# {'_id': ObjectId('625f328e5e80e0def19c0486'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'CRI - America/Costa Rica', ' Ingresos ': 88693.71186, ' Gastos ': 75048.52542}
# {'_id': ObjectId('625f328e5e80e0def19c0487'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'CRI - America/Costa Rica', ' Ingresos ': 15390.96765, ' Gastos ': 12373.13085}
# {'_id': ObjectId('625f328e5e80e0def19c0488'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'CRI - America/Costa Rica', ' Ingresos ': 6717.495507, ' Gastos ': 4133.843389}
# {'_id': ObjectId('625f328e5e80e0def19c0489'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'CZE - Europa/Republica Checa', ' Ingresos ': 19938.29314, ' Gastos ': 16377.88365}
# {'_id': ObjectId('625f328e5e80e0def19c048a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'CZE - Europa/Republica Checa', ' Ingresos ': 35235.21311, ' Gastos ': 22185.13418}
# {'_id': ObjectId('625f328e5e80e0def19c048b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'CZE - Europa/Republica Checa', ' Ingresos ': 109660.6122, ' Gastos ': 96448.49029}
# {'_id': ObjectId('625f328e5e80e0def19c048c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'CZE - Europa/Republica Checa', ' Ingresos ': 48848.81818, ' Gastos ': 32004.39812}
# {'_id': ObjectId('625f328e5e80e0def19c048d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'CZE - Europa/Republica Checa', ' Ingresos ': 195395.2727, ' Gastos ': 152918.0395}
# {'_id': ObjectId('625f328e5e80e0def19c048e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'CZE - Europa/Republica Checa', ' Ingresos ': 34225.28662, ' Gastos ': 30051.47118}
# {'_id': ObjectId('625f328e5e80e0def19c048f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'CZE - Europa/Republica Checa', ' Ingresos ': 17277.71704, ' Gastos ': 11518.47803}
# {'_id': ObjectId('625f328e5e80e0def19c0490'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'DEU - Europa/Alemania', ' Ingresos ': 1026702.586, ' Gastos ': 801450.2609}
# {'_id': ObjectId('625f328e5e80e0def19c0491'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'DEU - Europa/Alemania', ' Ingresos ': 1370898.009, ' Gastos ': 743712.1697}
# {'_id': ObjectId('625f328e5e80e0def19c0492'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'DEU - Europa/Alemania', ' Ingresos ': 4389389.037, ' Gastos ': 3353851.542}
# {'_id': ObjectId('625f328e5e80e0def19c0493'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'DEU - Europa/Alemania', ' Ingresos ': 2345310.809, ' Gastos ': 1547905.134}
# {'_id': ObjectId('625f328e5e80e0def19c0494'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'DEU - Europa/Alemania', ' Ingresos ': 5695754.821, ' Gastos ': 4192075.549}
# {'_id': ObjectId('625f328e5e80e0def19c0495'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'DEU - Europa/Alemania', ' Ingresos ': 1265723.294, ' Gastos ': 1079029.108}
# {'_id': ObjectId('625f328e5e80e0def19c0496'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'DEU - Europa/Alemania', ' Ingresos ': 679607.1094, ' Gastos ': 329918.3604}
# {'_id': ObjectId('625f328e5e80e0def19c0497'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'DOM - America/Republica Dominicana', ' Ingresos ': 23398.26598, ' Gastos ': 22395.48315}
# {'_id': ObjectId('625f328e5e80e0def19c0498'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'DOM - America/Republica Dominicana', ' Ingresos ': 41568.34799, ' Gastos ': 26079.62006}
# {'_id': ObjectId('625f328e5e80e0def19c0499'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'DOM - America/Republica Dominicana', ' Ingresos ': 96170.83898, ' Gastos ': 89948.01999}
# {'_id': ObjectId('625f328e5e80e0def19c049a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'DOM - America/Republica Dominicana', ' Ingresos ': 49772.62719, ' Gastos ': 35725.68574}
# {'_id': ObjectId('625f328e5e80e0def19c049b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'DOM - America/Republica Dominicana', ' Ingresos ': 113481.59, ' Gastos ': 92574.78938}
# {'_id': ObjectId('625f328e5e80e0def19c049c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'DOM - America/Republica Dominicana', ' Ingresos ': 36844.67208, ' Gastos ': 36402.53601}
# {'_id': ObjectId('625f328e5e80e0def19c049d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'DOM - America/Republica Dominicana', ' Ingresos ': 18757.2876, ' Gastos ': 12035.92621}
# {'_id': ObjectId('625f328e5e80e0def19c049e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'DZA - Africa/Argelia', ' Ingresos ': 98911.30769, ' Gastos ': 81087.08633}
# {'_id': ObjectId('625f328e5e80e0def19c049f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'DZA - Africa/Argelia', ' Ingresos ': 133149.8373, ' Gastos ': 93299.99312}
# {'_id': ObjectId('625f328e5e80e0def19c04a0'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'DZA - Africa/Argelia', ' Ingresos ': 351598.7891, ' Gastos ': 299929.054}
# {'_id': ObjectId('625f328e5e80e0def19c04a1'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'DZA - Africa/Argelia', ' Ingresos ': 152558.1186, ' Gastos ': 86542.06003}
# {'_id': ObjectId('625f328e5e80e0def19c04a2'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'DZA - Africa/Argelia', ' Ingresos ': 661833.0147, ' Gastos ': 626108.2649}
# {'_id': ObjectId('625f328e5e80e0def19c04a3'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'DZA - Africa/Argelia', ' Ingresos ': 133149.8373, ' Gastos ': 122117.4222}
# {'_id': ObjectId('625f328e5e80e0def19c04a4'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'DZA - Africa/Argelia', ' Ingresos ': 69237.91538, ' Gastos ': 45164.4248}
# {'_id': ObjectId('625f328e5e80e0def19c04a5'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'ECU - America/Ecuador', ' Ingresos ': 32386.53526, ' Gastos ': 27598.40828}
# {'_id': ObjectId('625f328e5e80e0def19c04a6'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'ECU - America/Ecuador', ' Ingresos ': 57219.66134, ' Gastos ': 40462.47481}
# {'_id': ObjectId('625f328e5e80e0def19c04a7'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'ECU - America/Ecuador', ' Ingresos ': 192578, ' Gastos ': 171246.2831}
# {'_id': ObjectId('625f328e5e80e0def19c04a8'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'ECU - America/Ecuador', ' Ingresos ': 62621.51748, ' Gastos ': 43765.48277}
# {'_id': ObjectId('625f328e5e80e0def19c04a9'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'ECU - America/Ecuador', ' Ingresos ': 235654.6579, ' Gastos ': 213945.8652}
# {'_id': ObjectId('625f328e5e80e0def19c04aa'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'ECU - America/Ecuador', ' Ingresos ': 56676.43671, ' Gastos ': 55009.48269}
# {'_id': ObjectId('625f328e5e80e0def19c04ab'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'ECU - America/Ecuador', ' Ingresos ': 26972.52108, ' Gastos ': 16345.34778}
# {'_id': ObjectId('625f328e5e80e0def19c04ac'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'EGY - Africa/Egipto', ' Ingresos ': 197689.5676, ' Gastos ': 178744.3173}
# {'_id': ObjectId('625f328e5e80e0def19c04ad'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'EGY - Africa/Egipto', ' Ingresos ': 344791.9057, ' Gastos ': 229154.005}
# {'_id': ObjectId('625f328e5e80e0def19c04ae'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'EGY - Africa/Egipto', ' Ingresos ': 975268.5333, ' Gastos ': 874365.7505}
# {'_id': ObjectId('625f328e5e80e0def19c04af'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'EGY - Africa/Egipto', ' Ingresos ': 386427.1547, ' Gastos ': 238940.7907}
# {'_id': ObjectId('625f328e5e80e0def19c04b0'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'EGY - Africa/Egipto', ' Ingresos ': 1280039.95, ' Gastos ': 1297327.087}
# {'_id': ObjectId('625f328e5e80e0def19c04b1'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'EGY - Africa/Egipto', ' Ingresos ': 298551.5918, ' Gastos ': 287182.506}
# {'_id': ObjectId('625f328e5e80e0def19c04b2'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'EGY - Africa/Egipto', ' Ingresos ': 159506.5358, ' Gastos ': 105028.919}
# {'_id': ObjectId('625f328e5e80e0def19c04b3'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'ESP - Europa/Espa�a', ' Ingresos ': 92850.03626, ' Gastos ': 92720.47807}
# {'_id': ObjectId('625f328e5e80e0def19c04b4'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'ESP - Europa/Espa�a', ' Ingresos ': 155940.4455, ' Gastos ': 108438.5867}
# {'_id': ObjectId('625f328e5e80e0def19c04b5'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'ESP - Europa/Espa�a', ' Ingresos ': 540593.5444, ' Gastos ': 500049.0286}
# {'_id': ObjectId('625f328e5e80e0def19c04b6'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'ESP - Europa/Espa�a', ' Ingresos ': 170713.7509, ' Gastos ': 94047.7573}
# {'_id': ObjectId('625f328e5e80e0def19c04b7'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'ESP - Europa/Espa�a', ' Ingresos ': 501581.6392, ' Gastos ': 441584.7585}
# {'_id': ObjectId('625f328e5e80e0def19c04b8'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'ESP - Europa/Espa�a', ' Ingresos ': 132932.8388, ' Gastos ': 129057.1912}
# {'_id': ObjectId('625f328e5e80e0def19c04b9'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'ESP - Europa/Espa�a', ' Ingresos ': 74736.43472, ' Gastos ': 44841.86083}
# {'_id': ObjectId('625f328e5e80e0def19c04ba'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'FIN - Europa/Finlandia', ' Ingresos ': 18661.79039, ' Gastos ': 19146.99694}
# {'_id': ObjectId('625f328e5e80e0def19c04bb'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'FIN - Europa/Finlandia', ' Ingresos ': 33387.10938, ' Gastos ': 19437.10411}
# {'_id': ObjectId('625f328e5e80e0def19c04bc'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'FIN - Europa/Finlandia', ' Ingresos ': 61935.50725, ' Gastos ': 60298.13177}
# {'_id': ObjectId('625f328e5e80e0def19c04bd'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'FIN - Europa/Finlandia', ' Ingresos ': 29472.75862, ' Gastos ': 18567.83793}
# {'_id': ObjectId('625f328e5e80e0def19c04be'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'FIN - Europa/Finlandia', ' Ingresos ': 152626.7857, ' Gastos ': 129133.1626}
# {'_id': ObjectId('625f328e5e80e0def19c04bf'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'FIN - Europa/Finlandia', ' Ingresos ': 21475.12563, ' Gastos ': 18790.73492}
# {'_id': ObjectId('625f328e5e80e0def19c04c0'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'FIN - Europa/Finlandia', ' Ingresos ': 13545.32488, ' Gastos ': 8794.785941}
# {'_id': ObjectId('625f328e5e80e0def19c04c1'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'FRA - Europa/Francia', ' Ingresos ': 150547.1377, ' Gastos ': 141077.2371}
# {'_id': ObjectId('625f328e5e80e0def19c04c2'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'FRA - Europa/Francia', ' Ingresos ': 264215.2785, ' Gastos ': 157208.0907}
# {'_id': ObjectId('625f328e5e80e0def19c04c3'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'FRA - Europa/Francia', ' Ingresos ': 703001.3661, ' Gastos ': 691637.7823}
# {'_id': ObjectId('625f328e5e80e0def19c04c4'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'FRA - Europa/Francia', ' Ingresos ': 285275.9167, ' Gastos ': 195783.805}
# {'_id': ObjectId('625f328e5e80e0def19c04c5'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'FRA - Europa/Francia', ' Ingresos ': 874846.1444, ' Gastos ': 765888.0337}
# {'_id': ObjectId('625f328e5e80e0def19c04c6'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'FRA - Europa/Francia', ' Ingresos ': 208849.2122, ' Gastos ': 194096.4593}
# {'_id': ObjectId('625f328e5e80e0def19c04c7'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'FRA - Europa/Francia', ' Ingresos ': 103464.0644, ' Gastos ': 72424.84507}
# {'_id': ObjectId('625f328e5e80e0def19c04c8'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'GBR - Europa/Reino Unido', ' Ingresos ': 145897.2754, ' Gastos ': 142909.2263}
# {'_id': ObjectId('625f328e5e80e0def19c04c9'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'GBR - Europa/Reino Unido', ' Ingresos ': 236644.378, ' Gastos ': 166503.7853}
# {'_id': ObjectId('625f328e5e80e0def19c04ca'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'GBR - Europa/Reino Unido', ' Ingresos ': 533825.6899, ' Gastos ': 461686.6215}
# {'_id': ObjectId('625f328e5e80e0def19c04cb'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'GBR - Europa/Reino Unido', ' Ingresos ': 234229.6395, ' Gastos ': 136969.5293}
# {'_id': ObjectId('625f328e5e80e0def19c04cc'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'GBR - Europa/Reino Unido', ' Ingresos ': 1059438.677, ' Gastos ': 1046329.998}
# {'_id': ObjectId('625f328e5e80e0def19c04cd'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'GBR - Europa/Reino Unido', ' Ingresos ': 182661.8408, ' Gastos ': 160791.282}
# {'_id': ObjectId('625f328e5e80e0def19c04ce'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'GBR - Europa/Reino Unido', ' Ingresos ': 97402.42433, ' Gastos ': 56337.2408}
# {'_id': ObjectId('625f328e5e80e0def19c04cf'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'GRC - Europa/Grecia', ' Ingresos ': 33644.90349, ' Gastos ': 30646.12689}
# {'_id': ObjectId('625f328e5e80e0def19c04d0'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'GRC - Europa/Grecia', ' Ingresos ': 55542.60339, ' Gastos ': 40855.03227}
# {'_id': ObjectId('625f328e5e80e0def19c04d1'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'GRC - Europa/Grecia', ' Ingresos ': 126038.9846, ' Gastos ': 115692.6668}
# {'_id': ObjectId('625f328e5e80e0def19c04d2'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'GRC - Europa/Grecia', ' Ingresos ': 68271.11667, ' Gastos ': 52011.29085}
# {'_id': ObjectId('625f328e5e80e0def19c04d3'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'GRC - Europa/Grecia', ' Ingresos ': 273084.4667, ' Gastos ': 265926.0125}
# {'_id': ObjectId('625f328e5e80e0def19c04d4'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'GRC - Europa/Grecia', ' Ingresos ': 41376.43434, ' Gastos ': 42016.38986}
# {'_id': ObjectId('625f328e5e80e0def19c04d5'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'GRC - Europa/Grecia', ' Ingresos ': 20793.2335, ' Gastos ': 12027.94043}
# {'_id': ObjectId('625f328e5e80e0def19c04d6'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'GTM - America/Guatemala', ' Ingresos ': 40241.16376, ' Gastos ': 43044.3461}
# {'_id': ObjectId('625f328e5e80e0def19c04d7'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'GTM - America/Guatemala', ' Ingresos ': 63553.28621, ' Gastos ': 45749.18615}
# {'_id': ObjectId('625f328e5e80e0def19c04d8'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'GTM - America/Guatemala', ' Ingresos ': 141772.7154, ' Gastos ': 138207.4802}
# {'_id': ObjectId('625f328e5e80e0def19c04d9'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'GTM - America/Guatemala', ' Ingresos ': 77438.87815, ' Gastos ': 55270.70863}
# {'_id': ObjectId('625f328e5e80e0def19c04da'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'GTM - America/Guatemala', ' Ingresos ': 209436.9659, ' Gastos ': 213751.3674}
# {'_id': ObjectId('625f328e5e80e0def19c04db'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'GTM - America/Guatemala', ' Ingresos ': 53576.89826, ' Gastos ': 50368.98147}
# {'_id': ObjectId('625f328e5e80e0def19c04dc'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'GTM - America/Guatemala', ' Ingresos ': 28224.27718, ' Gastos ': 21947.19794}
# {'_id': ObjectId('625f328e5e80e0def19c04dd'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'HUN - Europa/Hungria', ' Ingresos ': 19855.02115, ' Gastos ': 20187.27549}
# {'_id': ObjectId('625f328e5e80e0def19c04de'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'HUN - Europa/Hungria', ' Ingresos ': 32569.75079, ' Gastos ': 23867.95778}
# {'_id': ObjectId('625f328e5e80e0def19c04df'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'HUN - Europa/Hungria', ' Ingresos ': 76478.6, ' Gastos ': 71818.67114}
# {'_id': ObjectId('625f328e5e80e0def19c04e0'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'HUN - Europa/Hungria', ' Ingresos ': 38098.19557, ' Gastos ': 25116.98083}
# {'_id': ObjectId('625f328e5e80e0def19c04e1'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'HUN - Europa/Hungria', ' Ingresos ': 125909.8902, ' Gastos ': 121896.7748}
# {'_id': ObjectId('625f328e5e80e0def19c04e2'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'HUN - Europa/Hungria', ' Ingresos ': 30912.00898, ' Gastos ': 29476.41892}
# {'_id': ObjectId('625f328e5e80e0def19c04e3'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'HUN - Europa/Hungria', ' Ingresos ': 15596.08912, ' Gastos ': 10085.84905}
# {'_id': ObjectId('625f328e5e80e0def19c04e4'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'IDN - Asia/Indonesia', ' Ingresos ': 535072.6557, ' Gastos ': 555477.7397}
# {'_id': ObjectId('625f328e5e80e0def19c04e5'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'IDN - Asia/Indonesia', ' Ingresos ': 834234.6837, ' Gastos ': 506365.2851}
# {'_id': ObjectId('625f328e5e80e0def19c04e6'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'IDN - Asia/Indonesia', ' Ingresos ': 2194247.529, ' Gastos ': 2139830.191}
# {'_id': ObjectId('625f328e5e80e0def19c04e7'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'IDN - Asia/Indonesia', ' Ingresos ': 1231676.679, ' Gastos ': 731391.0326}
# {'_id': ObjectId('625f328e5e80e0def19c04e8'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'IDN - Asia/Indonesia', ' Ingresos ': 4662776, ' Gastos ': 4640085.57}
# {'_id': ObjectId('625f328e5e80e0def19c04e9'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'IDN - Asia/Indonesia', ' Ingresos ': 786492.3373, ' Gastos ': 759692.611}
# {'_id': ObjectId('625f328e5e80e0def19c04ea'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'IDN - Asia/Indonesia', ' Ingresos ': 358675.0769, ' Gastos ': 252352.748}
# {'_id': ObjectId('625f328e5e80e0def19c04eb'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'IND - Asia/India', ' Ingresos ': 1216075.733, ' Gastos ': 1074671.578}
# {'_id': ObjectId('625f328e5e80e0def19c04ec'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'IND - Asia/India', ' Ingresos ': 2383508.437, ' Gastos ': 1466774.423}
# {'_id': ObjectId('625f328e5e80e0def19c04ed'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'IND - Asia/India', ' Ingresos ': 4619202.398, ' Gastos ': 4147855.214}
# {'_id': ObjectId('625f328e5e80e0def19c04ee'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'IND - Asia/India', ' Ingresos ': 2327644.958, ' Gastos ': 1432396.897}
# {'_id': ObjectId('625f328e5e80e0def19c04ef'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'IND - Asia/India', ' Ingresos ': 11034761.28, ' Gastos ': 10852155.55}
# {'_id': ObjectId('625f328e5e80e0def19c04f0'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'IND - Asia/India', ' Ingresos ': 1664461.199, ' Gastos ': 1433286.033}
# {'_id': ObjectId('625f328e5e80e0def19c04f1'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'IND - Asia/India', ' Ingresos ': 877580.4261, ' Gastos ': 574966.486}
# {'_id': ObjectId('625f328e5e80e0def19c04f2'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'IRL - Europa/Irlanda', ' Ingresos ': 9492.261111, ' Gastos ': 8401.196616}
# {'_id': ObjectId('625f328e5e80e0def19c04f3'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'IRL - Europa/Irlanda', ' Ingresos ': 18438.20504, ' Gastos ': 12080.2033}
# {'_id': ObjectId('625f328e5e80e0def19c04f4'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'IRL - Europa/Irlanda', ' Ingresos ': 51258.21, ' Gastos ': 44423.782}
# {'_id': ObjectId('625f328e5e80e0def19c04f5'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'IRL - Europa/Irlanda', ' Ingresos ': 18176.67021, ' Gastos ': 9914.547389}
# {'_id': ObjectId('625f328e5e80e0def19c04f6'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'IRL - Europa/Irlanda', ' Ingresos ': 51775.9697, ' Gastos ': 45138.02486}
# {'_id': ObjectId('625f328e5e80e0def19c04f7'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'IRL - Europa/Irlanda', ' Ingresos ': 14479.72034, ' Gastos ': 12735.17572}
# {'_id': ObjectId('625f328e5e80e0def19c04f8'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'IRL - Europa/Irlanda', ' Ingresos ': 7708.001504, ' Gastos ': 4204.364457}
# {'_id': ObjectId('625f328e5e80e0def19c04f9'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'IRN - Asia/IrAn', ' Ingresos ': 169782.2344, ' Gastos ': 152096.585}
# {'_id': ObjectId('625f328e5e80e0def19c04fa'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'IRN - Asia/IrAn', ' Ingresos ': 299035.8065, ' Gastos ': 169020.2384}
# {'_id': ObjectId('625f328e5e80e0def19c04fb'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'IRN - Asia/IrAn', ' Ingresos ': 671747.1014, ' Gastos ': 547349.4901}
# {'_id': ObjectId('625f328e5e80e0def19c04fc'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'IRN - Asia/IrAn', ' Ingresos ': 383062.3967, ' Gastos ': 216513.5286}
# {'_id': ObjectId('625f328e5e80e0def19c04fd'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'IRN - Asia/IrAn', ' Ingresos ': 1571205.085, ' Gastos ': 1524804.449}
# {'_id': ObjectId('625f328e5e80e0def19c04fe'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'IRN - Asia/IrAn', ' Ingresos ': 260396.3483, ' Gastos ': 232986.2064}
# {'_id': ObjectId('625f328e5e80e0def19c04ff'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'IRN - Asia/IrAn', ' Ingresos ': 119768.863, ' Gastos ': 65328.47075}
# {'_id': ObjectId('625f328e5e80e0def19c0500'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'ISR - Asia/Israel', ' Ingresos ': 21769.3082, ' Gastos ': 18141.09017}
# {'_id': ObjectId('625f328e5e80e0def19c0501'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'ISR - Asia/Israel', ' Ingresos ': 30777.29781, ' Gastos ': 16787.61698}
# {'_id': ObjectId('625f328e5e80e0def19c0502'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'ISR - Asia/Israel', ' Ingresos ': 70632.79137, ' Gastos ': 58241.07358}
# {'_id': ObjectId('625f328e5e80e0def19c0503'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'ISR - Asia/Israel', ' Ingresos ': 43830.16964, ' Gastos ': 23907.36526}
# {'_id': ObjectId('625f328e5e80e0def19c0504'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'ISR - Asia/Israel', ' Ingresos ': 140256.5429, ' Gastos ': 125797.1054}
# {'_id': ObjectId('625f328e5e80e0def19c0505'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'ISR - Asia/Israel', ' Ingresos ': 30971.47634, ' Gastos ': 27327.77324}
# {'_id': ObjectId('625f328e5e80e0def19c0506'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'ISR - Asia/Israel', ' Ingresos ': 12427.79494, ' Gastos ': 7456.676962}
# {'_id': ObjectId('625f328e5e80e0def19c0507'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'ITA - Europa/Italia', ' Ingresos ': 129895.3573, ' Gastos ': 103916.2858}
# {'_id': ObjectId('625f328e5e80e0def19c0508'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'ITA - Europa/Italia', ' Ingresos ': 203331.6383, ' Gastos ': 125127.162}
# {'_id': ObjectId('625f328e5e80e0def19c0509'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'ITA - Europa/Italia', ' Ingresos ': 704169.5684, ' Gastos ': 633041.3292}
# {'_id': ObjectId('625f328e5e80e0def19c050a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'ITA - Europa/Italia', ' Ingresos ': 245040.6923, ' Gastos ': 154284.8803}
# {'_id': ObjectId('625f328e5e80e0def19c050b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'ITA - Europa/Italia', ' Ingresos ': 815806.2073, ' Gastos ': 724142.5885}
# {'_id': ObjectId('625f328e5e80e0def19c050c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'ITA - Europa/Italia', ' Ingresos ': 215793.9, ' Gastos ': 193996.5364}
# {'_id': ObjectId('625f328e5e80e0def19c050d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'ITA - Europa/Italia', ' Ingresos ': 89553.0241, ' Gastos ': 48847.10405}
# {'_id': ObjectId('625f328e5e80e0def19c050e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'JPN - Asia/Japon', ' Ingresos ': 282210.0244, ' Gastos ': 252187.6814}
# {'_id': ObjectId('625f328e5e80e0def19c050f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'JPN - Asia/Japon', ' Ingresos ': 370246.3878, ' Gastos ': 201952.5751}
# {'_id': ObjectId('625f328e5e80e0def19c0510'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'JPN - Asia/Japon', ' Ingresos ': 933783.1691, ' Gastos ': 839461.6369}
# {'_id': ObjectId('625f328e5e80e0def19c0511'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'JPN - Asia/Japon', ' Ingresos ': 531357.7866, ' Gastos ': 309958.7089}
# {'_id': ObjectId('625f328e5e80e0def19c0512'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'JPN - Asia/Japon', ' Ingresos ': 1443119.443, ' Gastos ': 1271319.509}
# {'_id': ObjectId('625f328e5e80e0def19c0513'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'JPN - Asia/Japon', ' Ingresos ': 341383.0941, ' Gastos ': 302143.658}
# {'_id': ObjectId('625f328e5e80e0def19c0514'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'JPN - Asia/Japon', ' Ingresos ': 165357.4362, ' Gastos ': 93462.89872}
# {'_id': ObjectId('625f328e5e80e0def19c0515'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'KEN - Africa/Kenia', ' Ingresos ': 112380.9364, ' Gastos ': 99491.81419}
# {'_id': ObjectId('625f328e5e80e0def19c0516'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'KEN - Africa/Kenia', ' Ingresos ': 171965.4597, ' Gastos ': 97551.31534}
# {'_id': ObjectId('625f328e5e80e0def19c0517'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'KEN - Africa/Kenia', ' Ingresos ': 416631.7642, ' Gastos ': 356451.6205}
# {'_id': ObjectId('625f328e5e80e0def19c0518'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'KEN - Africa/Kenia', ' Ingresos ': 174305.1259, ' Gastos ': 98878.54412}
# {'_id': ObjectId('625f328e5e80e0def19c0519'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'KEN - Africa/Kenia', ' Ingresos ': 582337.5795, ' Gastos ': 498180.4068}
# {'_id': ObjectId('625f328e5e80e0def19c051a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'KEN - Africa/Kenia', ' Ingresos ': 161658.3817, ' Gastos ': 131260.2664}
# {'_id': ObjectId('625f328e5e80e0def19c051b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'KEN - Africa/Kenia', ' Ingresos ': 81993.1312, ' Gastos ': 46065.23189}
# {'_id': ObjectId('625f328e5e80e0def19c051c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'KOR - Asia/Republica de Corea', ' Ingresos ': 103534.9352, ' Gastos ': 82647.88739}
# {'_id': ObjectId('625f328e5e80e0def19c051d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'KOR - Asia/Republica de Corea', ' Ingresos ': 222744.4821, ' Gastos ': 144624.8101}
# {'_id': ObjectId('625f328e5e80e0def19c051e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'KOR - Asia/Republica de Corea', ' Ingresos ': 375227.2819, ' Gastos ': 338662.5808}
# {'_id': ObjectId('625f328e5e80e0def19c051f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'KOR - Asia/Republica de Corea', ' Ingresos ': 188881.3007, ' Gastos ': 126224.814}
# {'_id': ObjectId('625f328e5e80e0def19c0520'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'KOR - Asia/Republica de Corea', ' Ingresos ': 755525.2027, ' Gastos ': 674306.2434}
# {'_id': ObjectId('625f328e5e80e0def19c0521'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'KOR - Asia/Republica de Corea', ' Ingresos ': 163476.2135, ' Gastos ': 152305.3389}
# {'_id': ObjectId('625f328e5e80e0def19c0522'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'KOR - Asia/Republica de Corea', ' Ingresos ': 74051.47682, ' Gastos ': 42273.73438}
# {'_id': ObjectId('625f328e5e80e0def19c0523'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'MEX - America/Mexico', ' Ingresos ': 282169.0774, ' Gastos ': 248386.0947}
# {'_id': ObjectId('625f328e5e80e0def19c0524'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'MEX - America/Mexico', ' Ingresos ': 398563.8219, ' Gastos ': 253457.0675}
# {'_id': ObjectId('625f328e5e80e0def19c0525'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'MEX - America/Mexico', ' Ingresos ': 1054053.083, ' Gastos ': 941818.6981}
# {'_id': ObjectId('625f328e5e80e0def19c0526'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'MEX - America/Mexico', ' Ingresos ': 518457.0041, ' Gastos ': 346472.3013}
# {'_id': ObjectId('625f328e5e80e0def19c0527'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'MEX - America/Mexico', ' Ingresos ': 2198972.81, ' Gastos ': 1767704.878}
# {'_id': ObjectId('625f328e5e80e0def19c0528'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'MEX - America/Mexico', ' Ingresos ': 356258.1648, ' Gastos ': 320632.3483}
# {'_id': ObjectId('625f328e5e80e0def19c0529'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'MEX - America/Mexico', ' Ingresos ': 179381.7482, ' Gastos ': 119876.4924}
# {'_id': ObjectId('625f328e5e80e0def19c052a'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'MYS - Asia/Malasia', ' Ingresos ': 65244.02259, ' Gastos ': 58904.88113}
# {'_id': ObjectId('625f328e5e80e0def19c052b'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'MYS - Asia/Malasia', ' Ingresos ': 106623.6208, ' Gastos ': 72504.06215}
# {'_id': ObjectId('625f328e5e80e0def19c052c'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'MYS - Asia/Malasia', ' Ingresos ': 264781.9917, ' Gastos ': 235967.4808}
# {'_id': ObjectId('625f328e5e80e0def19c052d'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'MYS - Asia/Malasia', ' Ingresos ': 154994.3366, ' Gastos ': 104362.8533}
# {'_id': ObjectId('625f328e5e80e0def19c052e'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'MYS - Asia/Malasia', ' Ingresos ': 496466.2344, ' Gastos ': 438308.7612}
# {'_id': ObjectId('625f328e5e80e0def19c052f'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'MYS - Asia/Malasia', ' Ingresos ': 84730.23733, ' Gastos ': 67219.32162}
# {'_id': ObjectId('625f328e5e80e0def19c0530'), 'Periodo': 'Q1 2019', 'TipoProducto': 'TV', 'Region': 'MYS - Asia/Malasia', ' Ingresos ': 41372.1862, ' Gastos ': 28190.1517}
# {'_id': ObjectId('625f328e5e80e0def19c0531'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Accesorios', 'Region': 'NGA - Africa/Nigeria', ' Ingresos ': 359747.853, ' Gastos ': 310490.07}
# {'_id': ObjectId('625f328e5e80e0def19c0532'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Aplicaciones', 'Region': 'NGA - Africa/Nigeria', ' Ingresos ': 643562.7682, ' Gastos ': 403959.3991}
# {'_id': ObjectId('625f328e5e80e0def19c0533'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Celulares', 'Region': 'NGA - Africa/Nigeria', ' Ingresos ': 1706326.972, ' Gastos ': 1511446.471}
# {'_id': ObjectId('625f328e5e80e0def19c0534'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Musica', 'Region': 'NGA - Africa/Nigeria', ' Ingresos ': 634776.9283, ' Gastos ': 384674.8186}
# {'_id': ObjectId('625f328e5e80e0def19c0535'), 'Periodo': 'Q1 2019', 'TipoProducto': 'PC', 'Region': 'NGA - Africa/Nigeria', ' Ingresos ': 3444252.593, ' Gastos ': 3002161.541}
# {'_id': ObjectId('625f328e5e80e0def19c0536'), 'Periodo': 'Q1 2019', 'TipoProducto': 'Tablets', 'Region': 'NGA - Africa/Nigeria', ' Ingresos ': 535993.1988, ' Gastos ': 470531.7344}
# ...
# {'_id': ObjectId('625f328e5e80e0def19c1636'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'RUS - Asia/Rusia', ' Ingresos ': 544688.2868, ' Gastos ': 363125.5245}
# {'_id': ObjectId('625f328e5e80e0def19c1637'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'RUS - Asia/Rusia', ' Ingresos ': 1586180.176, ' Gastos ': 1542152.456}
# {'_id': ObjectId('625f328e5e80e0def19c1638'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'RUS - Asia/Rusia', ' Ingresos ': 378851.4331, ' Gastos ': 294662.2257}
# {'_id': ObjectId('625f328e5e80e0def19c1639'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'RUS - Asia/Rusia', ' Ingresos ': 191944.6755, ' Gastos ': 125756.8564}
# {'_id': ObjectId('625f328e5e80e0def19c163a'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'SDN - Africa/SudAn', ' Ingresos ': 93094.33121, ' Gastos ': 71832.78718}
# {'_id': ObjectId('625f328e5e80e0def19c163b'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'SDN - Africa/SudAn', ' Ingresos ': 148133.2095, ' Gastos ': 76191.99426}
# {'_id': ObjectId('625f328e5e80e0def19c163c'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'SDN - Africa/SudAn', ' Ingresos ': 317735, ' Gastos ': 259457.7512}
# {'_id': ObjectId('625f328e5e80e0def19c163d'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'SDN - Africa/SudAn', ' Ingresos ': 146158.1, ' Gastos ': 90200.42743}
# {'_id': ObjectId('625f328e5e80e0def19c163e'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'SDN - Africa/SudAn', ' Ingresos ': 695990.9524, ' Gastos ': 583575.1986}
# {'_id': ObjectId('625f328e5e80e0def19c163f'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'SDN - Africa/SudAn', ' Ingresos ': 113889.4286, ' Gastos ': 93330.92659}
# {'_id': ObjectId('625f328e5e80e0def19c1640'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'SDN - Africa/SudAn', ' Ingresos ': 60899.20833, ' Gastos ': 32221.2175}
# {'_id': ObjectId('625f328e5e80e0def19c1641'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'SVK - Europa/Eslovaquia', ' Ingresos ': 15856.24621, ' Gastos ': 13849.12644}
# {'_id': ObjectId('625f328e5e80e0def19c1642'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'SVK - Europa/Eslovaquia', ' Ingresos ': 24551.60704, ' Gastos ': 15108.68125}
# {'_id': ObjectId('625f328e5e80e0def19c1643'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'SVK - Europa/Eslovaquia', ' Ingresos ': 60667.37681, ' Gastos ': 52356.77725}
# {'_id': ObjectId('625f328e5e80e0def19c1644'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'SVK - Europa/Eslovaquia', ' Ingresos ': 28671.56849, ' Gastos ': 17202.9411}
# {'_id': ObjectId('625f328e5e80e0def19c1645'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'SVK - Europa/Eslovaquia', ' Ingresos ': 110159.1842, ' Gastos ': 96214.98368}
# {'_id': ObjectId('625f328e5e80e0def19c1646'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'SVK - Europa/Eslovaquia', ' Ingresos ': 25447.10638, ' Gastos ': 22796.36613}
# {'_id': ObjectId('625f328e5e80e0def19c1647'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'SVK - Europa/Eslovaquia', ' Ingresos ': 12570.71772, ' Gastos ': 8380.478478}
# {'_id': ObjectId('625f328e5e80e0def19c1648'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'SWE - Europa/Suecia', ' Ingresos ': 22281.92616, ' Gastos ': 18568.2718}
# {'_id': ObjectId('625f328e5e80e0def19c1649'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'SWE - Europa/Suecia', ' Ingresos ': 36800.11498, ' Gastos ': 23657.21677}
# {'_id': ObjectId('625f328e5e80e0def19c164a'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'SWE - Europa/Suecia', ' Ingresos ': 96895.7156, ' Gastos ': 86363.5726}
# {'_id': ObjectId('625f328e5e80e0def19c164b'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'SWE - Europa/Suecia', ' Ingresos ': 47150.14732, ' Gastos ': 27504.2526}
# {'_id': ObjectId('625f328e5e80e0def19c164c'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'SWE - Europa/Suecia', ' Ingresos ': 162486.6615, ' Gastos ': 145906.39}
# {'_id': ObjectId('625f328e5e80e0def19c164d'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'SWE - Europa/Suecia', ' Ingresos ': 26536.76633, ' Gastos ': 21961.46179}
# {'_id': ObjectId('625f328e5e80e0def19c164e'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'SWE - Europa/Suecia', ' Ingresos ': 15716.71577, ' Gastos ': 10297.15861}
# {'_id': ObjectId('625f328e5e80e0def19c164f'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'THA - Asia/Tailandia', ' Ingresos ': 163605.8148, ' Gastos ': 143653.8862}
# {'_id': ObjectId('625f328e5e80e0def19c1650'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'THA - Asia/Tailandia', ' Ingresos ': 284990.7742, ' Gastos ': 161081.7419}
# {'_id': ObjectId('625f328e5e80e0def19c1651'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'THA - Asia/Tailandia', ' Ingresos ': 787251.7426, ' Gastos ': 696763.0365}
# {'_id': ObjectId('625f328e5e80e0def19c1652'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'THA - Asia/Tailandia', ' Ingresos ': 369825.2372, ' Gastos ': 209031.6558}
# {'_id': ObjectId('625f328e5e80e0def19c1653'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'THA - Asia/Tailandia', ' Ingresos ': 1060165.68, ' Gastos ': 839297.83}
# {'_id': ObjectId('625f328e5e80e0def19c1654'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'THA - Asia/Tailandia', ' Ingresos ': 211469.2181, ' Gastos ': 180821.5053}
# {'_id': ObjectId('625f328e5e80e0def19c1655'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'THA - Asia/Tailandia', ' Ingresos ': 119388.027, ' Gastos ': 76749.44595}
# {'_id': ObjectId('625f328e5e80e0def19c1656'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'TUR - Asia/Turquia', ' Ingresos ': 149489.4846, ' Gastos ': 118345.842}
# {'_id': ObjectId('625f328e5e80e0def19c1657'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'TUR - Asia/Turquia', ' Ingresos ': 243857.4779, ' Gastos ': 150066.1402}
# {'_id': ObjectId('625f328e5e80e0def19c1658'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'TUR - Asia/Turquia', ' Ingresos ': 578095.6993, ' Gastos ': 503018.3358}
# {'_id': ObjectId('625f328e5e80e0def19c1659'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'TUR - Asia/Turquia', ' Ingresos ': 324187, ' Gastos ': 189109.0833}
# {'_id': ObjectId('625f328e5e80e0def19c165a'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'TUR - Asia/Turquia', ' Ingresos ': 1312185.476, ' Gastos ': 1139529.492}
# {'_id': ObjectId('625f328e5e80e0def19c165b'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'TUR - Asia/Turquia', ' Ingresos ': 231562.1429, ' Gastos ': 205543.9246}
# {'_id': ObjectId('625f328e5e80e0def19c165c'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'TUR - Asia/Turquia', ' Ingresos ': 130185.3307, ' Gastos ': 86790.22047}
# {'_id': ObjectId('625f328e5e80e0def19c165d'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'TZA - Africa/Tanzania', ' Ingresos ': 129765.7173, ' Gastos ': 113940.6299}
# {'_id': ObjectId('625f328e5e80e0def19c165e'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'TZA - Africa/Tanzania', ' Ingresos ': 206827.9522, ' Gastos ': 116902.7556}
# {'_id': ObjectId('625f328e5e80e0def19c165f'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'TZA - Africa/Tanzania', ' Ingresos ': 412248.9116, ' Gastos ': 365402.4443}
# {'_id': ObjectId('625f328e5e80e0def19c1660'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'TZA - Africa/Tanzania', ' Ingresos ': 227821.7669, ' Gastos ': 151881.1779}
# {'_id': ObjectId('625f328e5e80e0def19c1661'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'TZA - Africa/Tanzania', ' Ingresos ': 776930.641, ' Gastos ': 655535.2284}
# {'_id': ObjectId('625f328e5e80e0def19c1662'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'TZA - Africa/Tanzania', ' Ingresos ': 188786.8847, ' Gastos ': 169908.1963}
# {'_id': ObjectId('625f328e5e80e0def19c1663'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'TZA - Africa/Tanzania', ' Ingresos ': 78498.17358, ' Gastos ': 50463.11158}
# {'_id': ObjectId('625f328e5e80e0def19c1664'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'UKR - Europa/Ucrania', ' Ingresos ': 134615.4639, ' Gastos ': 119822.5558}
# {'_id': ObjectId('625f328e5e80e0def19c1665'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'UKR - Europa/Ucrania', ' Ingresos ': 268166.7739, ' Gastos ': 151572.5244}
# {'_id': ObjectId('625f328e5e80e0def19c1666'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'UKR - Europa/Ucrania', ' Ingresos ': 729528.9656, ' Gastos ': 638337.8449}
# {'_id': ObjectId('625f328e5e80e0def19c1667'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'UKR - Europa/Ucrania', ' Ingresos ': 226153.9793, ' Gastos ': 142393.2462}
# {'_id': ObjectId('625f328e5e80e0def19c1668'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'UKR - Europa/Ucrania', ' Ingresos ': 737458.6283, ' Gastos ': 652693.2687}
# {'_id': ObjectId('625f328e5e80e0def19c1669'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'UKR - Europa/Ucrania', ' Ingresos ': 206848.1518, ' Gastos ': 179631.2897}
# {'_id': ObjectId('625f328e5e80e0def19c166a'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'UKR - Europa/Ucrania', ' Ingresos ': 106175.5772, ' Gastos ': 57913.95117}
# {'_id': ObjectId('625f328e5e80e0def19c166b'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'USA - America/Estados Unidos', ' Ingresos ': 2893184.025, ' Gastos ': 2383033.218}
# {'_id': ObjectId('625f328e5e80e0def19c166c'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'USA - America/Estados Unidos', ' Ingresos ': 5622215.748, ' Gastos ': 3457138.876}
# {'_id': ObjectId('625f328e5e80e0def19c166d'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'USA - America/Estados Unidos', ' Ingresos ': 14030662.33, ' Gastos ': 11447010.95}
# {'_id': ObjectId('625f328e5e80e0def19c166e'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'USA - America/Estados Unidos', ' Ingresos ': 7239565.473, ' Gastos ': 3777164.595}
# {'_id': ObjectId('625f328e5e80e0def19c166f'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'USA - America/Estados Unidos', ' Ingresos ': 17814211.71, ' Gastos ': 14050263.09}
# {'_id': ObjectId('625f328e5e80e0def19c1670'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'USA - America/Estados Unidos', ' Ingresos ': 5081618.091, ' Gastos ': 4326537.715}
# {'_id': ObjectId('625f328e5e80e0def19c1671'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'USA - America/Estados Unidos', ' Ingresos ': 2544887.383, ' Gastos ': 1564868.639}
# {'_id': ObjectId('625f328e5e80e0def19c1672'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'VEN - America/Venezuela', ' Ingresos ': 69916.04046, ' Gastos ': 59928.03468}
# {'_id': ObjectId('625f328e5e80e0def19c1673'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'VEN - America/Venezuela', ' Ingresos ': 116302.6442, ' Gastos ': 63437.80594}
# {'_id': ObjectId('625f328e5e80e0def19c1674'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'VEN - America/Venezuela', ' Ingresos ': 279126.3462, ' Gastos ': 243340.9172}
# {'_id': ObjectId('625f328e5e80e0def19c1675'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'VEN - America/Venezuela', ' Ingresos ': 149326.8519, ' Gastos ': 84402.13366}
# {'_id': ObjectId('625f328e5e80e0def19c1676'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'VEN - America/Venezuela', ' Ingresos ': 431981.25, ' Gastos ': 385026.7663}
# {'_id': ObjectId('625f328e5e80e0def19c1677'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'VEN - America/Venezuela', ' Ingresos ': 91632.38636, ' Gastos ': 72136.13395}
# {'_id': ObjectId('625f328e5e80e0def19c1678'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'VEN - America/Venezuela', ' Ingresos ': 49235.31208, ' Gastos ': 26855.62477}
# {'_id': ObjectId('625f328e5e80e0def19c1679'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'YEM - Asia/Yemen', ' Ingresos ': 58512.69231, ' Gastos ': 46322.54808}
# {'_id': ObjectId('625f328e5e80e0def19c167a'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'YEM - Asia/Yemen', ' Ingresos ': 94221.34441, ' Gastos ': 57982.36579}
# {'_id': ObjectId('625f328e5e80e0def19c167b'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'YEM - Asia/Yemen', ' Ingresos ': 213611.4041, ' Gastos ': 184349.5679}
# {'_id': ObjectId('625f328e5e80e0def19c167c'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'YEM - Asia/Yemen', ' Ingresos ': 112184.4065, ' Gastos ': 63408.57757}
# {'_id': ObjectId('625f328e5e80e0def19c167d'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'YEM - Asia/Yemen', ' Ingresos ': 371276.9643, ' Gastos ': 303772.0617}
# {'_id': ObjectId('625f328e5e80e0def19c167e'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'YEM - Asia/Yemen', ' Ingresos ': 89106.47143, ' Gastos ': 75183.58527}
# {'_id': ObjectId('625f328e5e80e0def19c167f'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'YEM - Asia/Yemen', ' Ingresos ': 49268.98104, ' Gastos ': 31021.21029}
# {'_id': ObjectId('625f328e5e80e0def19c1680'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'ZAF - Africa/SudAfrica', ' Ingresos ': 138475.1878, ' Gastos ': 113454.1538}
# {'_id': ObjectId('625f328e5e80e0def19c1681'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'ZAF - Africa/SudAfrica', ' Ingresos ': 190805.9273, ' Gastos ': 113896.4612}
# {'_id': ObjectId('625f328e5e80e0def19c1682'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'ZAF - Africa/SudAfrica', ' Ingresos ': 440518.3826, ' Gastos ': 348705.0776}
# {'_id': ObjectId('625f328e5e80e0def19c1683'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'ZAF - Africa/SudAfrica', ' Ingresos ': 227907.0799, ' Gastos ': 145860.5311}
# {'_id': ObjectId('625f328e5e80e0def19c1684'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'ZAF - Africa/SudAfrica', ' Ingresos ': 705776.7634, ' Gastos ': 577168.5532}
# {'_id': ObjectId('625f328e5e80e0def19c1685'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'ZAF - Africa/SudAfrica', ' Ingresos ': 209703.639, ' Gastos ': 175924.3501}
# {'_id': ObjectId('625f328e5e80e0def19c1686'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'ZAF - Africa/SudAfrica', ' Ingresos ': 104020.981, ' Gastos ': 59465.32746}
# {'_id': ObjectId('625f328e5e80e0def19c1687'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Accesorios', 'Region': 'NZL - Oceania/Nueva Zelanda', ' Ingresos ': 10993.81607, ' Gastos ': 9477.387701}
# {'_id': ObjectId('625f328e5e80e0def19c1688'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Aplicaciones', 'Region': 'NZL - Oceania/Nueva Zelanda', ' Ingresos ': 17997.0526, ' Gastos ': 10713.39697}
# {'_id': ObjectId('625f328e5e80e0def19c1689'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Celulares', 'Region': 'NZL - Oceania/Nueva Zelanda', ' Ingresos ': 47516.93898, ' Gastos ': 41006.10734}
# {'_id': ObjectId('625f328e5e80e0def19c168a'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Musica', 'Region': 'NZL - Oceania/Nueva Zelanda', ' Ingresos ': 26290.62523, ' Gastos ': 15057.35808}
# {'_id': ObjectId('625f328e5e80e0def19c168b'), 'Periodo': 'Q4 2021', 'TipoProducto': 'PC', 'Region': 'NZL - Oceania/Nueva Zelanda', ' Ingresos ': 99027.76744, ' Gastos ': 83854.98113}
# {'_id': ObjectId('625f328e5e80e0def19c168c'), 'Periodo': 'Q4 2021', 'TipoProducto': 'Tablets', 'Region': 'NZL - Oceania/Nueva Zelanda', ' Ingresos ': 16346.89305, ' Gastos ': 13292.60514}
# {'_id': ObjectId('625f328e5e80e0def19c168d'), 'Periodo': 'Q4 2021', 'TipoProducto': 'TV', 'Region': 'NZL - Oceania/Nueva Zelanda', ' Ingresos ': 6571.491561, ' Gastos ': 4343.310186}

# %%
#Convertir cursor a Json
cursor = collection.find()
list_cur = list(cursor)
json_data = dumps(list_cur)
json_data
# Out:
# '[{"_id": {"$oid": "625f328e5e80e0def19c042e"}, "Periodo": "Q1 2019", "TipoProducto": "Accesorios", "Region": "AGO - Africa/Angola", " Ingresos ": 66319.70378, " Gastos ": 56708.15251}, {"_id": {"$oid": "625f328e5e80e0def19c042f"}, "Periodo": "Q1 2019", "TipoProducto": "Aplicaciones", "Region": "AGO - Africa/Angola", " Ingresos ": 122357.2829, " Gastos ": 77039.77074}, {"_id": {"$oid": "625f328e5e80e0def19c0430"}, "Periodo": "Q1 2019", "TipoProducto": "Celulares", "Region": "AGO - Africa/Angola", " Ingresos ": 265278.8151, " Gastos ": 215226.2085}, {"_id": {"$oid": "625f328e5e80e0def19c0431"}, "Periodo": "Q1 2019", "TipoProducto": "Musica", "Region": "AGO - Africa/Angola", " Ingresos ": 130447.0207, " Gastos ": 86964.68044}, {"_id": {"$oid": "625f328e5e80e0def19c0432"}, "Periodo": "Q1 2019", "TipoProducto": "PC", "Region": "AGO - Africa/Angola", " Ingresos ": 394602.2375, " Gastos ": 326567.369}, {"_id": {"$oid": "625f328e5e80e0def19c0433"}, "Periodo": "Q1 2019", "TipoProducto": "Tablets", "Region": "AGO - Africa/Angola", " Ingresos ": 81152.13111, " Gastos ": 69217.99418}, {"_id": {"$oid": "625f328e5e80e0def19c0434"}, "Periodo": "Q1 2019", "TipoProducto": "TV", "Region": "AGO - Africa/Angola", " Ingresos ": 44777.55887, " Gastos ": 28193.2778}, {"_id": {"$oid": "625f328e5e80e0def19c0435"}, "Periodo": "Q1 2019", "TipoProducto": "Accesorios", "Region": "ARG - America/Argentina", " Ingresos ": 88128.95446, " Gastos ": 73914.60697}, {"_id": {"$oid": "625f328e5e80e0def19c0436"}, "Periodo": "Q1 2019", "TipoProducto": "Aplicaciones", "Region": "ARG - America/Argentina", " Ingresos ": 135405.1283, " Gastos ": 73857.3427}, {"_id": {"$oid": "625f328e5e80e0def19c0437"}, "Periodo": "Q1 2019", "TipoProducto": "Celulares", "Region": "ARG - America/Argentina", " Ingresos ": 464439.59, " Gastos ": 417526.5001}, {"_id": {"$oid": "625f328e5e80e0def19c0438"}, "Periodo": "Q1 2019", "TipoProducto": "Musica", "Region": "ARG - America/Argentina", " Ingresos ": 232219.795, " Gastos ": 146212.4635}, {"_id": {"$oid": "625f328e5e80e0def19c0439"}, "Periodo": "Q1 2019", "TipoProducto": "PC", "Region": "ARG - America/Argentina", " Ingresos ": 566389.7439, " Gastos ": 493775.6742}, {"_id": {"$oid": "625f328e5e80e0def19c043a"}, "Periodo": "Q1 2019", "TipoProducto": "Tablets", "Region": "ARG - America/Argentina", " Ingresos ": 152275.2754, " Gastos ": 131971.9054}, {"_id": {"$oid": "625f328e5e80e0def19c043b"}, "Periodo": "Q1 2019", "TipoProducto": "TV", "Region": "ARG - America/Argentina", " Ingresos ": 62932.19377, " Gastos ": 35570.37039}, {"_id": {"$oid": "625f328e5e80e0def19c043c"}, "Periodo": "Q1 2019", "TipoProducto": "Accesorios", "Region": "AUS - Oceania/Australia", " Ingresos ": 54365.02453, " Gastos ": 39867.68465}, {"_id": {"$oid": "625f328e5e80e0def19c043d"}, "Periodo": "Q1 2019", "TipoProducto": "Aplicaciones", "Region": "AUS - Oceania/Australia", " Ingresos ": 87845.92378, " Gastos ": 43124.36258}, {"_id": {"$oid": "625f328e5e80e0def19c043e"}, "Periodo": "Q1 2019", "TipoProducto": "Celulares", "Region": "AUS - Oceania/Australia", " Ingresos ": 246268.9145, " Gastos ": 197809.5475}, {"_id": {"$oid": "625f328e5e80e0def19c043f"}, "Periodo": "Q1 2019", "TipoProducto": "Musica", "Region": "AUS - Oceania/Australia", " Ingresos ": 114794.6733, " Gastos ": 65050.31487}, {"_id": {"$oid": "625f328e5e80e0def19c0440"}, "Periodo": "Q1 2019", "TipoProducto": "PC", "Region": "AUS - Oceania/Australia", " Ingresos ": 313189.8152, " Gastos ": 252509.2885}, {"_id": {"$oid": "625f328e5e80e0def19c0441"}, "Periodo": "Q1 2019", "TipoProducto": "Tablets", "Region": "AUS - Oceania/Australia", " Ingresos ": 92647.791, " Gastos ": 70749.22222}, {"_id": {"$oid": "625f328e5e80e0def19c0442"}, "Periodo": "Q1 2019", "TipoProducto": "TV", "Region": "AUS - Oceania/Australia", " Ingresos ": 36987.75738, " Gastos ": 19973.38899}, {"_id": {"$oid": "625f328e5e80e0def19c0443"}, "Periodo": "Q1 2019", "TipoProducto": "Accesorios", "Region": "AUT - Europa/Austria", " Ingresos ": 21115. ...

# %%
#Convertir cursor a Dataframe
df = pd.DataFrame(list_cur)
df
# Out:
#                            _id  Periodo  TipoProducto  \
# 0     625f328e5e80e0def19c042e  Q1 2019    Accesorios
# 1     625f328e5e80e0def19c042f  Q1 2019  Aplicaciones
# 2     625f328e5e80e0def19c0430  Q1 2019     Celulares
# 3     625f328e5e80e0def19c0431  Q1 2019        Musica
# 4     625f328e5e80e0def19c0432  Q1 2019            PC
# ...                        ...      ...           ...
# 4699  625f328e5e80e0def19c1689  Q4 2021     Celulares
# 4700  625f328e5e80e0def19c168a  Q4 2021        Musica
# 4701  625f328e5e80e0def19c168b  Q4 2021            PC
# 4702  625f328e5e80e0def19c168c  Q4 2021       Tablets
# 4703  625f328e5e80e0def19c168d  Q4 2021            TV
#
#                            Region      Ingresos         Gastos
# 0             AGO - Africa/Angola   66319.703780   56708.152510
# 1             AGO - Africa/Angola  122357.282900   77039.770740
# 2             AGO - Africa/Angola  265278.815100  215226.208500
# 3             AGO - Africa/Angola  130447.020700   86964.680440
# 4             AGO - Africa/Angola  394602.237500  326567.369000
# ...                           ...            ...            ...
# 4699  NZL - Oceania/Nueva Zelanda   47516.938980   41006.107340
# 4700  NZL - Oceania/Nueva Zelanda   26290.625230   15057.358080
# 4701  NZL - Oceania/Nueva Zelanda   99027.767440   83854.981130
# 4702  NZL - Oceania/Nueva Zelanda   16346.893050   13292.605140
# 4703  NZL - Oceania/Nueva Zelanda    6571.491561    4343.310186
#
# [4704 rows x 6 columns]

# %% [markdown]
# ### Instalación de !pip install requests

# %%
import requests
endpoint = 'http://localhost:3000/api/craigslists'
r = requests.get(endpoint)

# %%
r.json().keys()
# Out:
# dict_keys(['ok', 'craigslist'])

# %%
json = r.json()
result = json['craigslist']

# %%
normalized = pd.json_normalize(result)

df = pd.DataFrame.from_dict(normalized)

df.head()
# Out:
#                         _id          id  \
# 0  625f16695e80e0def195806a  7316814884
# 1  625f16695e80e0def195806b  7316814758
# 2  625f16695e80e0def195806c  7316814989
# 3  625f16695e80e0def195806d  7316743432
# 4  625f16695e80e0def195806e  7316356412
#
#                                                  url  region  \
# 0  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 1  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 2  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 3  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 4  https://auburn.craigslist.org/cto/d/auburn-uni...  auburn
#
#                       region_url precio  anio fabricante  \
# 0  https://auburn.craigslist.org  33590  2014        gmc
# 1  https://auburn.craigslist.org  22590  2010  chevrolet
# 2  https://auburn.craigslist.org  39590  2020  chevrolet
# 3  https://auburn.craigslist.org  30990  2017     toyota
# 4  https://auburn.craigslist.org  15000  2013       ford
#
#                      modelo  condicion  ...    tipo  color  \
# 0  sierra 1500 crew cab slt       good  ...  pickup  white
# 1            silverado 1500       good  ...  pickup   blue
# 2       silverado 1500 crew       good  ...  pickup    red
# 3      tundra double cab sr       good  ...  pickup    red
# 4                 f-150 xlt  excellent  ...   truck  black
#
#                                           imagen_url  \
# 0  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 1  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 2  https://images.craigslist.org/01212_jjirIWa0y0...
# 3  https://images.craigslist.org/00x0x_1y9kIOzGCF...
# 4  https://images.craigslist.org/00404_l4loxHvdQe...
#
#                                          descripcion estado     lat      long  \
# 0  Carvana is the safer way to buy a car During t...     al   32.59    -85.48
# 1  Carvana is the safer way to buy a car During t...     al   32.59    -85.48
# 2  Carvana is the safer way to buy a car During t...     al   32.59    -85.48
# 3  Carvana is the safer way to buy a car During t...     al   32.59    -85.48
# 4  2013 F-150 XLT V6 4 Door. Good condition. Leve...     al  32.592  -85.5189
#
#            fechapublicacion manejo    tamanio
# 0  2021-05-04T17:31:18.000Z    NaN        NaN
# 1  2021-05-04T17:31:08.000Z    NaN        NaN
# 2  2021-05-04T17:31:25.000Z    NaN        NaN
# 3  2021-05-04T15:41:31.000Z    NaN        NaN
# 4  2021-05-03T19:02:03.000Z    rwd  full-size
#
# [5 rows x 26 columns]
